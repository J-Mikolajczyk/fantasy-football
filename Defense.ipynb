# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.linear_model import Ridge

# %%
defense21csv = "/Users/henry/Desktop/CS345/Final_Project/fantasy-football/training_set/2021/2021_defense_stats.csv"
defense20csv = "/Users/henry/Desktop/CS345/Final_Project/fantasy-football/training_set/2020/2020_defense_stats.csv"
defense19csv = "/Users/henry/Desktop/CS345/Final_Project/fantasy-football/training_set/2019/2019_defense_stats.csv"

defense21csvPoints = "/Users/henry/Desktop/CS345/Final_Project/fantasy-football/training_set/2021/2022_defense_points.csv"
defense20csvPoints = "/Users/henry/Desktop/CS345/Final_Project/fantasy-football/training_set/2020/2021_defense_points.csv"
defense19csvPoints = "/Users/henry/Desktop/CS345/Final_Project/fantasy-football/training_set/2019/2020_defense_points.csv"

defense19 = pd.read_csv(defense19csv)
defense20 = pd.read_csv(defense20csv)
defense21 = pd.read_csv(defense21csv)

defensePoints19 = pd.read_csv(defense19csvPoints)
defensePoints20 = pd.read_csv(defense20csvPoints)
defensePoints21 = pd.read_csv(defense21csvPoints)

combined_stats = pd.concat([defense21, defense20, defense19])
combined_points = pd.concat([defensePoints21, defensePoints20, defensePoints19])
merged_df = pd.concat([combined_stats, combined_points['PPG']], axis=1)

for team in merged_df['DEFENSE'].unique():
    team_data_subset = merged_df[merged_df['DEFENSE'] == team]
    X_train = team_data_subset[['DEFENSE','TACKLES','SOLO','ASSIST','PASS DEF','SACKS','INT','FF','FR','SFTY','TD']]
    y_train = team_data_subset[['PPG']]
    print(y_train)
# Out:
#         PPG
# 0  5.941176
# 0  7.117647
# 0  6.437500
#         PPG
# 1  4.176471
# 1  3.470588
# 1  4.500000
#         PPG
# 2  7.294118
# 2  4.529412
# 2  8.812500
#         PPG
# 3  8.370000
# 3  8.647059
# 3  7.375000
#         PPG
# 4  6.352941
# 4  4.588235
# 4  6.062500
#         PPG
# 5  3.352941
# 5  5.764706
# 5  5.625000
#         PPG
# 6  6.500000
# 6  6.294118
# 6  2.812500
#         PPG
# 7  5.823529
# 7  6.117647
# 7  5.750000
#         PPG
# 8  9.764706
# 8  9.470588
# 8  4.812500
#         PPG
# 9  5.941176
# 9  6.470588
# 9  4.750000
#          PPG
# 10  5.294118
# 10  3.411765
# 10  1.687500
#          PPG
# 11  6.411765
# 11  6.705882
# 11  6.062500
#          PPG
# 12  6.823529
# 12  4.764706
# 12  2.562500
#          PPG
# 13  6.117647
# 13  7.176471
# 13  8.875000
#          PPG
# 14  8.176471
# 14  2.882353
# 14  3.250000
#          PPG
# 15  7.117647
# 15  7.411765
# 15  6.625000
#          PPG
# 16  4.294118
# 16  3.705882
# 16  2.437500
#          PPG
# ...

# %%
model = RandomForestRegressor()
